# %% [markdown]
# # Obtention des bases de données sur data.gouv.fr

# %%
#bibliothèques présentes sur le sspcloud
import requests
import pandas as pd

# %% [markdown]
# ## [Données géocodées issues du recensement des licences et clubs auprès des fédérations sportives agréées par le ministère chargé des sports](https://www.data.gouv.fr/fr/datasets/donnees-geocodees-issues-du-recensement-des-licences-et-clubs-aupres-des-federations-sportives-agreees-par-le-ministere-charge-des-sports/)

# %%
url_licence = 'https://static.data.gouv.fr/resources/donnees-geocodees-issues-du-recensement-des-licences-et-clubs-aupres-des-federations-sportives-agreees-par-le-ministere-charge-des-sports/20220823-100513/lic-data-2019.csv'
file_licence = url_licence.split('/')[-1] #encoding de ce fichier 'cp1250'
url_club = 'https://static.data.gouv.fr/resources/donnees-geocodees-issues-du-recensement-des-licences-et-clubs-aupres-des-federations-sportives-agreees-par-le-ministere-charge-des-sports/20220519-175014/clubs-data-2019.csv'
file_club = url_club.split('/')[-1]

# %% [markdown]
# ### téléchargement des bases de données

# %%
for nom, url in [[file_licence, url_licence],[file_club,url_club]]:
    response = requests.get(url, allow_redirects=True)
    if response.status_code == 200:
        with open(nom, 'wb') as f:
            f.write(response.content)
    else:
        print('Problème sur la requête pour le fichier')
# Out:
#   code_commune                libelle                region  fed_2019  \
# 0         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       101
# 1         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       103
# 2         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       105
# 3         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       108
# 4         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       109
#
#             nom_fed  l_2019  l_0_4_2019  l_5_9_2019  l_10_14_2019  \
# 0   FF d'athlétisme       8           0           0             4
# 1   FF de badminton      11           0           0             4
# 2  FF de basketball       1           0           0             0
# 3    FF de cyclisme       2           0           1             1
# 4   FF d'équitation      10           0           0             2
#
#    l_15_19_2019  ...  poph_2018  poph_0_4_2018  poph_5_9_2018  \
# 0             2  ...      388.0             15             30
# 1             1  ...      388.0             15             30
# 2             0  ...      388.0             15             30
# 3             0  ...      388.0             15             30
# 4             2  ...      388.0             15             30
#
#    poph_10_14_2018  poph_15_19_2018  poph_20_29_2018  poph_30_44_2018  \
# 0               20               29               25               70
# 1               20               29               25               70
# 2               20               29               25               70
# 3               20               29               25               70
# 4               20               29               25               70
#
#    poph_45_59_2018  poph_60_74_2018  poph_75_2018
# 0              122               51            26
# 1              122               51            26
# 2              122               51            26
# 3              122               51            26
# 4              122               51            26
#
# [5 rows x 68 columns]

# %%
df = pd.read_csv(file_licence, header = 0, encoding = 'cp1250', sep=';')
# Out:
# /var/mobile/Containers/Data/Application/0A3C2606-A8FD-4CEC-BFC6-BC0A895B4DC8/Library/Application Support/com.rationalmatter.junoapp/python-home/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3175: DtypeWarning: Columns (0,49,50,51,52,53,57,59,60,61,62,63,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
licence.head()
# Out:
#   code_commune                libelle                region  fed_2019  \
# 0         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       101
# 1         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       103
# 2         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       105
# 3         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       108
# 4         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       109
#
#             nom_fed  l_2019  l_0_4_2019  l_5_9_2019  l_10_14_2019  \
# 0   FF d'athlétisme       8           0           0             4
# 1   FF de badminton      11           0           0             4
# 2  FF de basketball       1           0           0             0
# 3    FF de cyclisme       2           0           1             1
# 4   FF d'équitation      10           0           0             2
#
#    l_15_19_2019  ...  poph_2018  poph_0_4_2018  poph_5_9_2018  \
# 0             2  ...      388.0             15             30
# 1             1  ...      388.0             15             30
# 2             0  ...      388.0             15             30
# 3             0  ...      388.0             15             30
# 4             2  ...      388.0             15             30
#
#    poph_10_14_2018  poph_15_19_2018  poph_20_29_2018  poph_30_44_2018  \
# 0               20               29               25               70
# 1               20               29               25               70
# 2               20               29               25               70
# 3               20               29               25               70
# 4               20               29               25               70
#
#    poph_45_59_2018  poph_60_74_2018  poph_75_2018
# 0              122               51            26
# 1              122               51            26
# 2              122               51            26
# 3              122               51            26
# 4              122               51            26
#
# [5 rows x 68 columns]

# %%
club.head()
# Out:
#   code_commune                commune                region  code_federation  \
# 0        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              109
# 1        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              133
# 2        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              211
# 3        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              605
# 4        01004      Ambérieu-En-Bugey  Auvergne-Rhône-Alpes              101
#
#                                       nom_federation  total_clubs_2019  \
# 0                                    FF d'équitation                 1
# 1                                        FF de rugby                 1
# 2                                 FF du sport boules                 2
# 3  Union sportive de l'enseignement du premier degré                 1
# 4                                    FF d'athlétisme                 2
#
#    clubs_sportifs_2019  etablissements_prof_2019
# 0                    0                         1
# 1                    1                         0
# 2                    2                         0
# 3                    1                         0
# 4                    2                         0

# %% [markdown]
# ### Ouverture direct

# %%
licence = pd.read_csv(url_licence, header = 0, encoding = 'cp1250', sep=';')
club = pd.read_csv(url_club, header = 0, encoding = 'cp1250', sep=';')
# Out:
# /var/mobile/Containers/Data/Application/0A3C2606-A8FD-4CEC-BFC6-BC0A895B4DC8/Library/Application Support/com.rationalmatter.junoapp/python-home/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3175: DtypeWarning: Columns (0,49,50,51,52,53,57,59,60,61,62,63,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /var/mobile/Containers/Data/Application/0A3C2606-A8FD-4CEC-BFC6-BC0A895B4DC8/Library/Application Support/com.rationalmatter.junoapp/python-home/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3175: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
licence.head()
# Out:
#   code_commune                libelle                region  fed_2019  \
# 0         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       101
# 1         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       103
# 2         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       105
# 3         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       108
# 4         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       109
#
#             nom_fed  l_2019  l_0_4_2019  l_5_9_2019  l_10_14_2019  \
# 0   FF d'athlétisme       8           0           0             4
# 1   FF de badminton      11           0           0             4
# 2  FF de basketball       1           0           0             0
# 3    FF de cyclisme       2           0           1             1
# 4   FF d'équitation      10           0           0             2
#
#    l_15_19_2019  ...  poph_2018  poph_0_4_2018  poph_5_9_2018  \
# 0             2  ...      388.0             15             30
# 1             1  ...      388.0             15             30
# 2             0  ...      388.0             15             30
# 3             0  ...      388.0             15             30
# 4             2  ...      388.0             15             30
#
#    poph_10_14_2018  poph_15_19_2018  poph_20_29_2018  poph_30_44_2018  \
# 0               20               29               25               70
# 1               20               29               25               70
# 2               20               29               25               70
# 3               20               29               25               70
# 4               20               29               25               70
#
#    poph_45_59_2018  poph_60_74_2018  poph_75_2018
# 0              122               51            26
# 1              122               51            26
# 2              122               51            26
# 3              122               51            26
# 4              122               51            26
#
# [5 rows x 68 columns]

# %%
club.head()
# Out:
#   code_commune                commune                region  code_federation  \
# 0        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              109
# 1        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              133
# 2        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              211
# 3        01001  Abergement-Clémenciat  Auvergne-Rhône-Alpes              605
# 4        01004      Ambérieu-En-Bugey  Auvergne-Rhône-Alpes              101
#
#                                       nom_federation  total_clubs_2019  \
# 0                                    FF d'équitation                 1
# 1                                        FF de rugby                 1
# 2                                 FF du sport boules                 2
# 3  Union sportive de l'enseignement du premier degré                 1
# 4                                    FF d'athlétisme                 2
#
#    clubs_sportifs_2019  etablissements_prof_2019
# 0                    0                         1
# 1                    1                         0
# 2                    2                         0
# 3                    1                         0
# 4                    2                         0

# %% [markdown]
# # Tests d'encoding
# En raison d'un encoding particulier des données des licenciés, on a utilisé ce petit code pour tester l'encoding (test sur l'ouverture par pandas et sur le résultat graphique (bonne lecture des caractères français)).

# %%
import pandas as pd

codecs = ['cp1250','ascii','big5','big5hkscs','cp037','cp273','cp424','cp437','cp500','cp720','cp737','cp775','cp850','cp852','cp855',
          'cp856','cp857','cp858','cp860','cp861','cp862','cp863','cp864','cp865','cp866','cp869','cp874','cp875','cp932','cp949',
          'cp950','cp1006','cp1026','cp1125','cp1140','cp1250','cp1251','cp1252','cp1253','cp1254','cp1255','cp1256','cp1257','cp1258',
          'euc_jp','euc_jis_2004','euc_jisx0213','euc_kr','gb2312','gbk','gb18030','hz','iso2022_jp','iso2022_jp_1','iso2022_jp_2',
          'iso2022_jp_2004','iso2022_jp_3','iso2022_jp_ext','iso2022_kr','latin_1','iso8859_2','iso8859_3','iso8859_4','iso8859_5','iso8859_6',
          'iso8859_7','iso8859_8','iso8859_9','iso8859_10','iso8859_11','iso8859_13','iso8859_14','iso8859_15','iso8859_16','johab','koi8_r','koi8_t',
          'koi8_u','kz1048','mac_cyrillic','mac_greek','mac_iceland','mac_latin2','mac_roman','mac_turkish','ptcp154','shift_jis','shift_jis_2004',
          'shift_jisx0213','utf_32','utf_32_be','utf_32_le','utf_16','utf_16_be','utf_16_le','utf_7','utf_8','utf_8_sig']


for x in range(len(codecs)):
    print(x,': Now checking use of:', codecs[x])
    try:
        df = pd.read_csv('liste_licence.csv', header = 0, encoding = (codecs[x]), sep=';')
        print(df.head())
        print(input('Press any key...'))
    except:
        print('I can\'t load data for', codecs[x], '\n')
        print(input('Press any key...'))
# Out:
# 0 : Now checking use of: cp1250
# /tmp/ipykernel_183/3570628605.py:16: DtypeWarning: Columns (0,49,50,51,52,53,57,59,60,61,62,63,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('liste_licence.csv', header = 0, encoding = (codecs[x]), sep=';')
#   code_commune                libelle                region  fed_2019  \
# 0         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       101
# 1         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       103
# 2         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       105
# 3         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       108
# 4         1001  Abergement-Clémenciat  Auvergne-Rhône-Alpes       109
#
#             nom_fed  l_2019  l_0_4_2019  l_5_9_2019  l_10_14_2019  \
# 0   FF d'athlétisme       8           0           0             4
# 1   FF de badminton      11           0           0             4
# 2  FF de basketball       1           0           0             0
# 3    FF de cyclisme       2           0           1             1
# 4   FF d'équitation      10           0           0             2
#
#    l_15_19_2019  ...  poph_2018  poph_0_4_2018  poph_5_9_2018  \
# 0             2  ...      388.0             15             30
# 1             1  ...      388.0             15             30
# 2             0  ...      388.0             15             30
# 3             0  ...      388.0             15             30
# 4             2  ...      388.0             15             30
#
#    poph_10_14_2018  poph_15_19_2018  poph_20_29_2018  poph_30_44_2018  \
# 0               20               29               25               70
# 1               20               29               25               70
# 2               20               29               25               70
# 3               20               29               25               70
# 4               20               29               25               70
#
#    poph_45_59_2018  poph_60_74_2018  poph_75_2018
# 0              122               51            26
# 1              122               51            26
# 2              122               51            26
# 3              122               51            26
# 4              122               51            26
#
# [5 rows x 68 columns]

# %% [markdown]
# ## [Données des équipements sportifs](https://equipements.sports.gouv.fr/explore/dataset/data-es/table/)

# %% [markdown]
# ##### Commandes et api root

# %%
api_root = "https://equipements.sports.gouv.fr/api/v2/"
#'https://equipements.sports.gouv.fr/api/records/1.0/search/' => url de la première API
dataset = 'data-es'

extension = 'json'

cmd_facet = f'catalog/datasets/{dataset}/facets/' #pour avoir la liste des facets = je ne sais pas

cmd_dataset_info = f'catalog/datasets/{dataset}/' #pour obtenir les infos notamment la table des variables, voir jsute en dessous

cmd_export = f'catalog/datasets/{dataset}/exports/{extension}'

cmd = api_root+cmd_dataset_info # schéma générale : mettre api_root + cmd_spécifique
select = "numinstallation, nominstallation, codeinsee AS codeINSEE, adresse, codepostal, commune, caract3 AS accesibilite_handicap, numequipement, nomequipement, codetypequipement, typequipement, famille, coordgpsx, coordgpsy, caract25 AS acces_libre, caract117 AS adressequipement, caract118 AS annee_miseservice, nom_commune"
where = 'tagequipement="validé"'
url_export =  f"{api_root}{cmd_export}?dataset={dataset}&format={extension}&select={select}&where={where}"
#ne pas oublier de remplir les paramètres spécifiques
url_info =  f"{api_root}{cmd_dataset_info}?dataset={dataset}"

# %%
def get_es(url):
    """fonction qui a pour but à partir d'une URL de requet de transformer en dataframe utilisable"""

    req = requests.get(url)
    wb = req.json()
    #print(wb)
    df = pd.json_normalize(wb)

    #dpe = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude), crs = 4326)
    #dpe = dpe.dropna(subset = ['longitude', 'latitude'])

    return df

# %% [markdown]
# ##### Table de variables de la base

# %%
equipement_infos = get_es(url_info) 
equipement_infos.head()
# Out:
#                                                links dataset.dataset_id  \
# 0  [{'rel': 'self', 'href': 'https://equipements....            data-es
#
#   dataset.dataset_uid  dataset.has_records           dataset.features  \
# 0           da_oenr36                 True  [geo, analyze, timeserie]
#
#   dataset.visibility dataset.attachments  dataset.data_visible  \
# 0             domain                  []                  True
#
#                                       dataset.fields  \
# 0  [{'name': 'numinstallation', 'annotations': {}...
#
#   dataset.metas.default.title  ... dataset.metas.default.records_count  \
# 0                     Data ES  ...                              332439
#
#   dataset.metas.default.attributions dataset.metas.default.source_domain  \
# 0                               None                                None
#
#   dataset.metas.default.source_domain_title  \
# 0                                      None
#
#   dataset.metas.default.source_domain_address  \
# 0                                        None
#
#   dataset.metas.default.source_dataset dataset.metas.default.shared_catalog  \
# 0                                 None                                 None
#
#   dataset.metas.default.federated dataset.metas.default.oauth_scope  \
# 0                           False                              None
#
#    dataset.metas.default.parent_domain
# 0                         sgsocialgouv
#
# [1 rows x 40 columns]

# %%
table_var = pd.DataFrame(equipement_infos['dataset.fields'][0])
table_var
# Out:
#                 name      annotations                        description  \
# 0    numinstallation               {}  Numéro de l'installation sportive
# 1    nominstallation               {}     Nom de l'installation sportive
# 2            adresse               {}     Numéro, type et nom de la voie
# 3         codepostal               {}                               None
# 4            commune               {}              Libellé de la commune
# ..               ...              ...                                ...
# 209               ct               {}                               None
# 210         code2016               {}                               None
# 211        code_dept               {}                               None
# 212         nom_dept  {'facet': True}                               None
# 213         code_reg               {}                               None
#
#                                  label  type
# 0    Numéro de l'installation sportive  text
# 1       Nom de l'installation sportive  text
# 2       Numéro, type et nom de la voie  text
# 3                          Code postal  text
# 4                              Commune  text
# ..                                 ...   ...
# 209                                 CT   int
# 210                           Code2016  text
# 211                                DEP  text
# 212                    Nom département  text
# 213                                REG  text
#
# [214 rows x 5 columns]

# %%
for i in table_var.index:
    print("name : ", table_var['name'][i], " label : ",table_var['label'][i])
# Out:
# name :  numinstallation  label :  Numéro de l'installation sportive
# name :  nominstallation  label :  Nom de l'installation sportive
# name :  adresse  label :  Numéro, type et nom de la voie
# name :  codepostal  label :  Code postal
# name :  commune  label :  Commune
# name :  codeinsee  label :  Code insee de la commune
# name :  actif  label :  Statut de la fiche d'enquête
# name :  taginstallation  label :  Etat de la fiche d'enquête
# name :  date_creation  label :  Date de création de la fiche d'enquête
# name :  date_etat  label :  Date de changement d'état de la fiche d'enquête
# name :  date_valid  label :  Date de validation de la fiche d'enquête
# name :  caract3  label :  Accessibilité de l'installation en faveur des personnes en situation de handicap
# name :  caract4  label :  Date d'enquête
# name :  caract5  label :  Installation gardiennée
# name :  caract6  label :  Installation gardiennée avec logement de gardien sur place
# name :  caract7  label :  Possibilité d'hébergement dans l'installation
# name :  caract8  label :  Installation implantée sur plusieurs communes
# name :  caract9  label :  Possibilité de restauration dans l'installation
# name :  caract10  label :  Nombre d'équipements rattachés à l'installation
# name :  caract11  label :  Nombre de lits de l'installation
# name :  caract12  label :  Nombre de places de parking réservées à l'installation
# name :  caract13  label :  Dont nombre de place de parking réservées aux personnes en situation de handicap
# name :  caract15  label :  Accessibilité de l'installation en transport en commun
# name :  caract16  label :  Installation particulière
# name :  caract17  label :  Emprise foncière de l'installation
# name :  caract18  label :  Etat de la fiche 2
# name :  caract19  label :  Type de particularité de l'installation
# name :  caract20  label :  Accessibilité de l'installation en fonction du type handicap
# name :  caract21  label :  Accessibilité de l'installation en transport en commun des différents mode
# name :  caract22  label :  Type de l'enquête
# name :  numequipement  label :  Numéro de l'équipement sportif
# name :  nomequipement  label :  Nom de l'équipement sportif
# name :  codetypequipement  label :  Code du type d'équipement sportif
# name :  typequipement  label :  Type d'équipement sportif
# name :  famille  label :  Famille d'équipement sportif
# name :  tagequipement  label :  Etat de la fiche d'enquête de l'équipement sportif
# name :  coordgpsx  label :  Longitude (WGS84)
# name :  coordgpsy  label :  Latitude (WGS84)
# name :  caract23  label :  Etat de la fiche 1
# name :  caract24  label :  Eclairage de l'aire d'évolution
# name :  caract25  label :  Equipement d'accès libre
# name :  caract26  label :  Aménagements d'information
# name :  caract27  label :  Aménagements de confort
# name :  caract74  label :  Nombre de vestiaires sportifs
# name :  caract28  label :  Soumis à la procédure de l'homologation préfectorale
# name :  caract29  label :  Arrêté d'ouverture au public
# name :  caract30  label :  Démarche pour la qualité environnementale
# name :  caract31  label :  Locaux complémentaires
# name :  caract32  label :  Derniers gros travaux réalisés
# name :  caract33  label :  Ouverture exclusivement saisonnière
# name :  caract34  label :  Présence de douches
# name :  caract35  label :  Présence de sanitaires
# name :  caract36  label :  Présence de vestiaires sportifs chauffés
# name :  caract37  label :  Aire d'évolution chauffée
# name :  caract38  label :  Gestion en DSP
# name :  caract39  label :  Présence d'un treuil
# name :  caract40  label :  Présence de moyen d'alerte
# name :  caract41  label :  Existence d'une aide publique à l'investissement
# name :  caract42  label :  Présence d'une tour d'arrivée (si stade)
# name :  caract43  label :  Présence de locaux pédagogiques
# name :  caract44  label :  Présence de locaux techniques
# name :  caract45  label :  Présence d'une signalétique de sécurité
# name :  caract46  label :  Présence d'une pataugeoire
# name :  caract47  label :  Aménagements complémentaires des bassins
# name :  caract48  label :  Aménagement complémentaire de station de ski
# name :  caract49  label :  Accessibilité partielle ou totale aux personnes à mobilité réduite
# name :  caract50  label :  Accessibilité aux personnes à mobilité réduite à l'accueil
# name :  caract51  label :  Accessibilité aux personnes à mobilité réduite à l'aire de jeu
# name :  caract52  label :  Accessibilité aux personnes à mobilité réduite aux cheminements
# name :  caract53  label :  Accessibilité aux personnes à mobilité réduite aux douches
# name :  caract54  label :  Accessibilité aux personnes à mobilité réduite aux sanitaires
# name :  caract55  label :  Accessibilité aux personnes à mobilité réduite aux tribunes
# name :  caract56  label :  Accessibilité aux personnes à mobilité réduite aux vestiaires
# name :  caract57  label :  Accessibilité partielle ou totale aux personnes en situation de handicap sensoriel
# name :  caract58  label :  Accessibilité aux personnes en situation de handicap sensoriel à l'aire de jeu
# name :  caract59  label :  Accessibilité aux personnes en situation de handicap sensoriel aux cheminements
# name :  caract60  label :  Accessibilité aux personnes en situation de handicap sensoriel aux sanitaires
# name :  caract61  label :  Accessibilité aux personnes en situation de handicap sensoriel - signalétique
# name :  caract62  label :  Accessibilité aux personnes en situation de handicap sensoriel aux tribunes
# name :  caract63  label :  Accessibilité aux personnes en situation de handicap sensoriel aux vestiaires
# name :  caract64  label :  Date de l'homologation préfectorale
# name :  caract65  label :  Date des derniers gros travaux
# name :  caract66  label :  catégorie ERP de l'établissement
# name :  caract67  label :  Hauteur de l'aire d'évolution
# name :  caract68  label :  Largeur de l'aire d'évolution
# name :  caract69  label :  Longueur de l'aire d'évolution
# name :  caract70  label :  Surface de l'aire d'évolution
# name :  caract71  label :  Nombre de couloirs/pistes/postes/jeux/pas
# name :  caract72  label :  Nombre de places assises en tribune
# name :  caract73  label :  Nombre de vestiaires arbitres/enseignants
# name :  caract75  label :  SAE: nombre de couloirs de la structure
# name :  caract76  label :  SAE: hauteur maximale de la structure
# name :  caract77  label :  SAE: surface totale de la structure
# name :  caract78  label :  Longueur du bassin
# name :  caract79  label :  Largeur du bassin
# name :  caract80  label :  Surface du bassin
# name :  caract81  label :  Profondeur minimale du bassin
# name :  caract82  label :  Profondeur maximale du bassin
# name :  caract83  label :  Nombre de couloirs des bassins mixtes et sportifs
# name :  caract84  label :  Surface des plages du bassin
# name :  caract85  label :  Nombre total de tremplins
# name :  caract86  label :  Nombre de tremplins de 1 mètre
# name :  caract87  label :  Nombre de tremplins de 3 mètres
# name :  caract88  label :  Nombre total de plate-formes
# name :  caract89  label :  Nombre de plate-forme de 3 mètres
# name :  caract90  label :  Nombre de plate-forme de 5 mètres
# name :  caract91  label :  Nombre de plate-forme de 10 mètres
# name :  caract92  label :  Nombre de plate-forme de 7, 5 mètres
# name :  caract93  label :  Longueur de la piste
# name :  caract94  label :  Longueur de la ligne droite d'arrivée
# name :  caract95  label :  Nombre de couloirs dans la ligne droite d'arrivée
# name :  caract96  label :  Nombre de couloirs hors ligne droite
# name :  caract97  label :  Rivière de steeple
# name :  caract98  label :  Nombre total d'aires de saut
# name :  caract99  label :  Nombre d'aires de saut en hauteur
# name :  caract100  label :  Nombre d'aires de saut en longueur
# name :  caract101  label :  Nombre d'aires de saut en longueur et triple saut
# name :  caract102  label :  Nombre d'aires de saut à la perche
# name :  caract103  label :  Nombre total d'aires de lancer
# name :  caract104  label :  Nombre d'aires de lancer de poids
# name :  caract105  label :  Nombre d'aires de lancer de disque
# name :  caract106  label :  Nombre d'aires de lancer de javelot
# name :  caract107  label :  Nombre d'aires de lancer de marteau
# name :  caract108  label :  Nombre d'aires de lancer de mixte disque-marteau
# name :  caract109  label :  Altitude la plus basse de la station de ski
# name :  caract110  label :  Altitude la plus haute de la station de ski
# name :  caract111  label :  Débit horaire maximal
# name :  caract112  label :  Nombre total de kilomètres de piste de ski alpin
# name :  caract113  label :  Nombre total de kilomètres de piste de fond/nordique
# name :  caract114  label :  Nombre total de kilomètres de piste bénificiant d'un enneigement artificiel
# name :  caract115  label :  Nombre total de remontées mécaniques
# name :  caract116  label :  Nom du bâtiment
# name :  caract117  label :  Adresse internet de l'équipement
# name :  caract118  label :  Année de mise en service
# name :  caract119  label :  Prénom de la personne ressource
# name :  caract120  label :  Nom de la personne ressource
# name :  caract121  label :  Email de la personne ressource
# name :  caract122  label :  Téléphone de la personne ressource
# name :  caract123  label :  Nom du propriétaire
# name :  caract124  label :  Prénom du propriétaire
# name :  caract125  label :  Adresse du propriétaire
# name :  caract126  label :  Code postal du propriétaire
# name :  caract127  label :  Commune de propriétaire
# name :  caract128  label :  Téléphone du propriétaire
# name :  caract129  label :  Fax du propriétaire
# name :  caract130  label :  Courriel du propriétaire
# name :  caract131  label :  Nom du propriétaire secondaire
# name :  caract132  label :  Prénom du propriétaire secondaire
# name :  caract133  label :  Adresse du propriétaire secondaire
# name :  caract134  label :  Code postal du propriétaire secondaire
# name :  caract135  label :  Commune de prorpriétaire secondaire
# name :  caract136  label :  Téléphone du propriétaire secondaire
# name :  caract137  label :  Fax du propriétaire secondaire
# name :  caract138  label :  Courriel du popriétaire secondaire
# name :  caract139  label :  Nom du gestionnaire
# name :  caract140  label :  Nom du co-gestionnaire
# name :  caract141  label :  Niveau de difficulté le plus élevé
# name :  caract142  label :  Niveau de difficulté le plus bas
# name :  caract144  label :  Nom de la personne ayant établi la déclaration
# name :  caract145  label :  Prénom de la personne ayant établi la déclaration
# name :  caract146  label :  Courriel de la personne ayant établi la déclaration
# name :  caract147  label :  Adresse de la personne ayant établi la déclaration
# name :  caract148  label :  Code postal de la personne ayant établi la déclaration
# name :  caract149  label :  Commune de la personne ayant établi la déclaration
# name :  caract150  label :  Commune de rédaction de la déclaration
# name :  caract151  label :  Date de rédaction de la déclaration
# name :  caract152  label :  Types d'aménagements d'information
# name :  caract153  label :  Types d'aménagements de confort
# name :  caract154  label :  Type d'ERP de l'établissement
# name :  caract155  label :  Type d'utilisation
# name :  caract156  label :  Types de locaux complémentaires
# name :  caract157  label :  Motifs des derniers gros travaux
# name :  caract158  label :  Types de chauffage - source d'énergie
# name :  caract159  label :  Types d'utilisateur
# name :  caract160  label :  Type de pas de tir
# name :  caract161  label :  Types d'accès pour le public
# name :  caract162  label :  Types d'accès pour les secours
# name :  caract163  label :  Types d'aménagements complémentaires des bassins
# name :  caract164  label :  Types d'aménagements complémentaires de station de ski
# name :  caract165  label :  Fonction de la personne ressource
# name :  caract166  label :  Civilité de la personne ressource
# name :  caract167  label :  Nature du sol
# name :  caract168  label :  Nature de l'équipement sportif
# name :  caract169  label :  Période de mise en service
# name :  caract170  label :  Période de l'homologation préfectorale
# name :  caract171  label :  Période des derniers gros travaux
# name :  caract172  label :  Type de déclaration
# name :  caract173  label :  Type de propriétaire
# name :  caract174  label :  Type de propriétaire secondaire
# name :  caract175  label :  Type de gestionnaire
# name :  caract176  label :  Type du co-gestionnaire
# name :  caract177  label :  Situation de l'équipement espace ou site
# name :  caract178  label :  Forme du bassin
# name :  caract179  label :  Inscription de l'équipement suite à une déclaration
# name :  caract180  label :  Accessibilité juridique
# name :  caract181  label :  Equipement inscrit au PDESI / PDIPR
# name :  atlas  label :  Atlas
# name :  coordonnees  label :  coordonnees
# name :  cocode_deptostal  label :  cocode_deptostal
# name :  artmin  label :  ARTMIN
# name :  cdc  label :  CDC
# name :  artmaj  label :  ARTMAJ
# name :  nom_region  label :  Nom région
# name :  ar  label :  AR
# name :  cheflieu  label :  CHEFLIEU
# name :  tncc  label :  TNCC
# name :  ncc  label :  NCC
# name :  com  label :  COM
# name :  nom_commune  label :  Nom Commune
# name :  ct  label :  CT
# name :  code2016  label :  Code2016
# name :  code_dept  label :  DEP
# name :  nom_dept  label :  Nom département
# name :  code_reg  label :  REG

# %% [markdown]
# ###### Ouverture de la base

# %%
equipements = get_es(url_export)

# %%
equipements.head()
# Out:
#   numinstallation  ... annee_miseservice
# 0      I190370001  ...              2000
# 1      I190370007  ...              None
# 2      I190380004  ...              2009
# 3      I190390001  ...              None
# 4      I190400001  ...              2008
#
# [5 rows x 18 columns]
